# %%
class Person:
    def __init__(self, name, age, country):
        self.name = name
        self.age = age
        self.country = country
    
    def display_details(self):
        print(f"Name: {self.name}, Age: {self.age}, Country: {self.country}")

person1 = Person("Alice", 30, "USA")
person2 = Person("Bob", 25, "Canada")

person1.display_details()
person2.display_details()
# Out:
# Name: Alice, Age: 30, Country: USA
# Name: Bob, Age: 25, Country: Canada

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def calculate_area(self):
        return self.width * self.height
    
    def calculate_perimeter(self):
        return 2 * (self.width + self.height)

rect = Rectangle(10, 5)
print(f"Area: {rect.calculate_area()}")
print(f"Perimeter: {rect.calculate_perimeter()}")
# Out:
# Area: 50
# Perimeter: 30

# %%
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    def display_details(self):
        print(f"Make: {self.make}, Model: {self.model}, Year: {self.year}")

class Car(Vehicle):
    def __init__(self, make, model, year, doors):
        super().__init__(make, model, year)
        self.doors = doors
    
    def display_details(self):
        super().display_details()
        print(f"Doors: {self.doors}")

car = Car("Toyota", "Camry", 2020, 4)
car.display_details()
# Out:
# Make: Toyota, Model: Camry, Year: 2020
# Doors: 4

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.account_number = account_number
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance: {self.balance}")
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance: {self.balance}")
        else:
            print("Insufficient funds")

account1 = BankAccount("12345", 1000)
account2 = BankAccount("67890", 500)

account1.deposit(200)
account1.withdraw(150)
account2.deposit(300)
account2.withdraw(100)
# Out:
# Deposited 200. New balance: 1200
# Withdrew 150. New balance: 1050
# Deposited 300. New balance: 800
# Withdrew 100. New balance: 700

# %%
import math

class Shape:
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def calculate_area(self):
        return math.pi * self.radius ** 2

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height
    
    def calculate_area(self):
        return 0.5 * self.base * self.height

circle = Circle(5)
triangle = Triangle(10, 8)

print(f"Circle area: {circle.calculate_area()}")
print(f"Triangle area: {triangle.calculate_area()}")
# Out:
# Circle area: 78.53981633974483
# Triangle area: 40.0

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    
    def calculate_annual_salary(self):
        return self.salary * 12

class Manager(Employee):
    def __init__(self, name, salary, department):
        super().__init__(name, salary)
        self.department = department
    
    def calculate_annual_salary(self):
        base = super().calculate_annual_salary()
        bonus = base * 0.1  
        return base + bonus

manager1 = Manager("John", 5000, "HR")
manager2 = Manager("Jane", 6000, "IT")

print(f"{manager1.name}'s annual salary: {manager1.calculate_annual_salary()}")
print(f"{manager2.name}'s annual salary: {manager2.calculate_annual_salary()}")
# Out:
# John's annual salary: 66000.0
# Jane's annual salary: 79200.0

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    
    def display_details(self):
        print(f"Title: {self.title}, Author: {self.author}, Year: {self.year}")

class Ebook(Book):
    def __init__(self, title, author, year, price):
        super().__init__(title, author, year)
        self.price = price
    
    def display_details(self):
        super().display_details()
        print(f"Price: ${self.price}")

ebook = Ebook("Python Guide", "Alice", 2023, 29.99)
ebook.display_details()
# Out:
# Title: Python Guide, Author: Alice, Year: 2023
# Price: $29.99

# %%
class Animal:
    def __init__(self, species, sound):
        self.species = species
        self.sound = sound
    
    def make_sound(self):
        print(f"The {self.species} makes {self.sound}")

class Dog(Animal):
    def __init__(self, species, sound, color):
        super().__init__(species, sound)
        self.color = color
    
    def make_sound(self):
        print(f"The {self.color} {self.species} makes {self.sound}")

dog = Dog("dog", "woof", "brown")
dog.make_sound()
# Out:
# The brown dog makes woof

# %%
class Bank:
    def __init__(self, name):
        self.name = name
        self.branches = []
    
    def add_branch(self, branch):
        self.branches.append(branch)
        print(f"Added branch: {branch}")
    
    def remove_branch(self, branch):
        if branch in self.branches:
            self.branches.remove(branch)
            print(f"Removed branch: {branch}")
        else:
            print(f"Branch {branch} not found")
    
    def display_branches(self):
        print(f"Branches of {self.name}: {self.branches}")

bank = Bank("National Bank")
bank.add_branch("Downtown")
bank.add_branch("Uptown")
bank.display_branches()
bank.remove_branch("Downtown")
bank.display_branches()
# Out:
# Added branch: Downtown
# Added branch: Uptown
# Branches of National Bank: ['Downtown', 'Uptown']
# Removed branch: Downtown
# Branches of National Bank: ['Uptown']

# %%
class Product:
    def __init__(self, product_id, name, price):
        self.product_id = product_id
        self.name = name
        self.price = price
    
    def calculate_total_price(self, quantity):
        return self.price * quantity

class PersonalCareProduct(Product):
    def __init__(self, product_id, name, price, warranty_period):
        super().__init__(product_id, name, price)
        self.warranty_period = warranty_period
    
    def calculate_total_price(self, quantity):
        base_total = super().calculate_total_price(quantity)
        warranty_cost = self.warranty_period * 10
        return base_total + warranty_cost

product = PersonalCareProduct("P001", "Shampoo", 15.0, 2)
print(f"Total price for 3 units: ${product.calculate_total_price(3)}")
# Out:
# Total price for 3 units: $65.0

# %%
class BankAccount:
    def __init__(self, account_number, holder_name, balance=0):
        self.account_number = account_number
        self.holder_name = holder_name
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount} to {self.holder_name}'s account. New balance: {self.balance}")
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} from {self.holder_name}'s account. New balance: {self.balance}")
        else:
            print("Insufficient funds")
    
    def transfer(self, amount, to_account):
        if amount <= self.balance:
            self.balance -= amount
            to_account.balance += amount
            print(f"Transferred {amount} from {self.holder_name} to {to_account.holder_name}")
        else:
            print("Insufficient funds for transfer")

account1 = BankAccount("12345", "Alice", 1000)
account2 = BankAccount("67890", "Bob", 500)
account3 = BankAccount("11111", "Charlie", 200)

account1.deposit(200)
account1.withdraw(150)
account2.transfer(100, account3)
print(f"Account1 balance: {account1.balance}")
print(f"Account2 balance: {account2.balance}")
print(f"Account3 balance: {account3.balance}")
# Out:
# Deposited 200 to Alice's account. New balance: 1200
# Withdrew 150 from Alice's account. New balance: 1050
# Transferred 100 from Bob to Charlie
# Account1 balance: 1050
# Account2 balance: 400
# Account3 balance: 300

# %%
class University:
    def __init__(self, name):
        self.name = name
        self.departments = []
    
    def add_department(self, department):
        self.departments.append(department)
        print(f"Added department: {department}")
    
    def remove_department(self, department):
        if department in self.departments:
            self.departments.remove(department)
            print(f"Removed department: {department}")
        else:
            print(f"Department {department} not found")
    
    def display_departments(self):
        print(f"Departments of {self.name}: {self.departments}")

university = University("State University")
university.add_department("Computer Science")
university.add_department("Mathematics")
university.display_departments()
university.remove_department("Mathematics")
university.display_departments()
# Out:
# Added department: Computer Science
# Added department: Mathematics
# Departments of State University: ['Computer Science', 'Mathematics']
# Removed department: Mathematics
# Departments of State University: ['Computer Science']
